# %% [markdown]
# <a href="https://colab.research.google.com/github/dame-demi/DesignOptimization/blob/main/HW3b_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bayesian-optimization 

import numpy as np
import matplotlib.pyplot as plt

def black_box_function(x1,x2):
    return (4 - 2.1*x1**2 + (x1**4)/3)*x1**2 + x1*x2 + (-4 + 4*x2**2)*x2**2 

from bayes_opt import BayesianOptimization

# Bounded region of parameter space
pbounds = {'x1': (-3, 3), 'x2': (-2, 2)}

optimizer = BayesianOptimization(
    f=black_box_function,
    pbounds=pbounds,
    random_state=1,
)

optimizer.maximize(
    init_points=2,
    n_iter=50,
)

x1 = np.arange(-0.9, 1.8, 0.1)
y1 = np.arange(-1.8, 0.4, 0.1)
xx, yy = np.meshgrid(x1, y1)
z=black_box_function(xx,yy)
h = plt.contourf(x1, y1, z)
plt.axis('scaled')
plt.show()

print(optimizer.max)
for i, res in enumerate(optimizer.res):
    print("Iteration {}: \n\t{}".format(i, res))
# Out:
# ...
# |   iter    |  target   |    x1     |    x2     |
# -------------------------------------------------
# |  1        | -0.265    | -0.4979   |  0.8813   |
# |  2        |  110.1    | -2.999    | -0.7907   |
# |  3        |  14.48    | -2.347    | -0.5245   |
# |  4        |  3.791    |  1.98     |  0.6406   |
# |  5        |  3.61     | -2.104    |  0.5152   |
# |  6        |  20.73    | -2.484    |  1.035    |
# |  7        |  8.23     | -0.6262   | -1.354    |
# |  8        |  12.31    |  2.326    | -0.2112   |
# |  9        | -0.06557  | -0.4062   | -0.5919   |
# |  10       |  0.4875   |  0.6594   | -0.4285   |
# |  11       | -0.262    |  0.3192   |  0.8082   |
# |  12       |  5.892    | -2.109    | -0.3733   |
# |  13       |  33.52    | -2.599    |  0.1371   |
# |  14       |  2.428    | -0.9648   | -0.9004   |
# |  15       |  0.1915   | -1.854    |  0.6938   |
# |  16       |  19.85    |  2.459    | -0.3357   |
# |  17       |  1.168    | -1.992    |  0.7364   |
# ...
